# %%
import json
import numpy as np
from arango import ArangoClient

# %%
file_path = "CVE_dump.json"


def load_json(file_path):
    with open(file_path, "r", encoding="utf-8") as json_file:
        data = json.load(json_file)
    return data


def add_VI_data(db, data):
    if not db.has_collection("CVE_VI"):
        collection = db.create_collection("CVE_VI")
    else:
        collection = db["CVE_VI"]
    count = 0
    for entry in data:
        entry["_key"] = entry["_id"]
        if not collection.has(entry["_key"]):
            collection.insert(entry)

# %%
client = ArangoClient()
BRON_db = client.db("BRON", username="root", password="changeme")
collections = BRON_db.collections()

# %%
data = load_json(file_path)
add_VI_data(BRON_db, data)

# %%
def build_vocab(db):

    aql_fetch = """
    FOR vuln IN CVE_VI
    RETURN {key: vuln._key, threat_type: vuln.threats[*].type}"""
    
    cursor = db.aql.execute(aql_fetch)

    threat_vocab = set()

    if db.has_graph('threat_graph'):
        threat_graph = db.graph('threat_graph')
    else:
        threat_graph = db.create_graph('threat_graph')

    if not db.has_collection("CVE_THREATS_VI"):
        threat_collection = db.create_collection("CVE_THREATS_VI")
    else:
        threat_collection = db["CVE_THREATS_VI"]

    if threat_graph.has_edge_definition('threat_edges'):
        threat_edges = threat_graph.edge_collection('threat_edges')
    else:
        threat_edges = threat_graph.create_edge_definition(
            edge_collection='threat_edges',
            from_vertex_collections=['CVE_VI'],
            to_vertex_collections=['CVE_THREATS_VI']
    )

    for document in cursor:
        print(document)
        for threat_type in document["threat_type"]:

            if threat_type not in threat_vocab:

                threat_vocab.add(threat_type)
                threat_doc = {"type" : threat_type, "_key" : threat_type}
                if not threat_collection.has(threat_doc["_key"]):
                    threat_collection.insert(threat_doc)

            edge = {
                "_from": "CVE_VI/" + document["key"],
                "_to": "CVE_THREATS_VI/" + threat_type
            }
            print(edge)
            threat_edges.insert(edge)

    print(threat_vocab)

# %%
def build_tags_vocab(db):

    batch_size = 1000

    aql_fetch = """
    FOR vuln IN CVE_VI
    RETURN {key: vuln._key, threat_type: vuln.threats[*].tags[*]}"""
    
    cursor = db.aql.execute(aql_fetch)

    threat_vocab = set()

    if db.has_graph('threat_type_graph'):
        threat_graph = db.graph('threat_type_graph')
    else:
        threat_graph = db.create_graph('threat_type_graph')

    if not db.has_collection("CVE_THREAT_TYPES_VI"):
        threat_collection = db.create_collection("CVE_THREAT_TYPES_VI")
    else:
        threat_collection = db["CVE_THREAT_TYPES_VI"]

    if threat_graph.has_edge_definition('threat_type_edges'):
        threat_edges = threat_graph.edge_collection('threat_type_edges')
    else:
        threat_edges = threat_graph.create_edge_definition(
            edge_collection='threat_type_edges',
            from_vertex_collections=['CVE_VI'],
            to_vertex_collections=['CVE_THREAT_TYPES_VI']
    )
        
        
    batch_edge_inserts = []
    batch_threat_inserts = []

    count = 0
    for document in cursor:
        if count % batch_size == 0:
            
            print(f"Processing count {count}")
            threat_edges.insert_many(batch_edge_inserts)
            # Batch insert threat types
            threat_collection.insert_many(batch_threat_inserts)

            # Reset the batch lists
            batch_edge_inserts = []
            batch_threat_inserts = []
        
        if len(document["threat_type"]):
            threat_types = [item for sublist in document["threat_type"] for item in sublist]
                    
        # print("threat types:" + str(threat_types))
        for threat_type in threat_types:

            if threat_type not in threat_vocab:
                threat_type = threat_type.replace(" ", "")
                threat_vocab.add(threat_type)
                threat_doc = {"type" : threat_type, "_key" : threat_type}
                # print(threat_doc)
                if not threat_collection.has(threat_doc["_key"]):
                    print("insert attempted")
                    batch_threat_inserts.append(threat_doc)

            edge = {
                "_from": "CVE_VI/" + document["key"],
                "_to": "CVE_THREAT_TYPES_VI/" + threat_type
            }
            # print(edge)
            batch_edge_inserts.append(edge)
        count += 1

    if batch_edge_inserts:
        print("Processing the final batch")
        threat_edges.insert_many(batch_edge_inserts)
    if batch_threat_inserts:
        threat_collection.insert_many(batch_threat_inserts)

# %%
build_tags_vocab(BRON_db)
# Out:
# Processing count 0
# Processing count 1000
# Processing count 2000
# Processing count 3000
# Processing count 4000
# Processing count 5000
# Processing count 6000
# Processing count 7000
# Processing count 8000
# Processing count 9000
# Processing count 10000
# Processing count 11000
# Processing count 12000
# Processing count 13000
# Processing count 14000
# Processing count 15000
# Processing count 16000
# Processing count 17000
# Processing count 18000
# Processing count 19000
# Processing count 20000
# Processing count 21000
# Processing count 22000
# Processing count 23000
# Processing count 24000
# Processing count 25000
# Processing count 26000
# Processing count 27000
# Processing count 28000
# Processing count 29000
# Processing count 30000
# Processing count 31000
# Processing count 32000
# Processing count 33000
# Processing count 34000
# Processing count 35000
# Processing count 36000
# Processing count 37000
# Processing count 38000
# Processing count 39000
# Processing count 40000
# Processing count 41000
# Processing count 42000
# insert attempted
# Processing count 43000
# Processing count 44000
# Processing count 45000
# Processing count 46000
# Processing count 47000
# Processing count 48000
# Processing count 49000
# Processing count 50000
# Processing count 51000
# Processing count 52000
# Processing count 53000
# Processing count 54000
# Processing count 55000
# Processing count 56000
# Processing count 57000
# Processing count 58000
# Processing count 59000
# Processing count 60000
# Processing count 61000
# Processing count 62000
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# insert attempted
# Processing count 63000
# Processing count 64000
# Processing count 65000
# Processing count 66000
# insert attempted
# Processing count 67000
# Processing count 68000
# Processing count 69000
# Processing count 70000
# Processing count 71000
# Processing count 72000
# Processing count 73000
# Processing count 74000
# Processing count 75000
# Processing count 76000
# Processing count 77000
# Processing count 78000
# Processing count 79000
# Processing count 80000
# Processing count 81000
# Processing count 82000
# Processing count 83000
# Processing count 84000
# Processing count 85000
# Processing count 86000
# Processing count 87000
# Processing count 88000
# Processing count 89000
# Processing count 90000
# Processing count 91000
# Processing count 92000
# Processing count 93000
# Processing count 94000
# Processing count 95000
# Processing count 96000
# Processing count 97000
# Processing count 98000
# Processing count 99000
# Processing count 100000
# Processing count 101000
# Processing count 102000
# Processing count 103000
# Processing count 104000
# Processing count 105000
# Processing count 106000
# Processing count 107000
# Processing count 108000
# Processing count 109000
# Processing count 110000
# Processing count 111000
# Processing count 112000
# Processing count 113000
# Processing count 114000
# Processing count 115000
# Processing count 116000
# Processing count 117000
# Processing count 118000
# Processing count 119000
# Processing count 120000
# Processing count 121000
# Processing count 122000
# Processing count 123000
# Processing count 124000
# Processing count 125000
# Processing count 126000
# Processing count 127000
# Processing count 128000
# Processing count 129000
# Processing count 130000
# Processing count 131000
# Processing count 132000
# Processing count 133000
# insert attempted
# Processing count 134000
# Processing count 135000
# Processing count 136000
# Processing count 137000
# Processing count 138000
# Processing count 139000
# Processing count 140000
# Processing count 141000
# Processing count 142000
# Processing count 143000
# Processing count 144000
# Processing count 145000
# Processing count 146000
# Processing count 147000
# Processing count 148000
# Processing count 149000
# Processing count 150000
# Processing count 151000
# Processing count 152000
# Processing count 153000
# Processing count 154000
# Processing count 155000
# Processing count 156000
# Processing count 157000
# Processing count 158000
# Processing count 159000
# Processing count 160000
# Processing count 161000
# Processing count 162000
# Processing count 163000
# Processing count 164000
# Processing count 165000
# Processing count 166000
# Processing count 167000
# Processing count 168000
# Processing count 169000
# Processing count 170000
# Processing count 171000
# Processing count 172000
# Processing count 173000
# Processing count 174000
# Processing count 175000
# Processing count 176000
# Processing count 177000
# Processing count 178000
# Processing count 179000
# Processing count 180000
# Processing count 181000
# Processing count 182000
# Processing count 183000
# Processing count 184000
# Processing count 185000
# Processing count 186000
# Processing count 187000
# Processing count 188000
# Processing count 189000
# Processing count 190000
# Processing count 191000
# Processing count 192000
# Processing count 193000
# Processing count 194000
# Processing count 195000
# Processing count 196000
# Processing count 197000
# Processing count 198000
# Processing count 199000
# Processing count 200000
# Processing count 201000
# Processing count 202000
# Processing count 203000
# Processing count 204000
# Processing count 205000
# Processing count 206000
# Processing count 207000
# Processing count 208000
# Processing count 209000
# Processing count 210000
# Processing count 211000
# Processing count 212000
# Processing count 213000
# Processing count 214000
# Processing count 215000
# Processing count 216000
# Processing count 217000
# Processing count 218000
# Processing count 219000
# Processing count 220000
# Processing count 221000
# Processing count 222000
# Processing count 223000
# Processing count 224000
# Processing count 225000
# Processing count 226000
# Processing count 227000
# Processing count 228000
# Processing count 229000
# Processing count 230000
# Processing count 231000
# Processing count 232000
# Processing count 233000
# Processing count 234000
# Processing count 235000
# Processing count 236000
# Processing count 237000
# Processing count 238000
# Processing count 239000
# Processing count 240000
# Processing count 241000
# Processing count 242000
# Processing count 243000
# Processing count 244000
# Processing count 245000
# Processing count 246000
# Processing count 247000
# Processing count 248000
# Processing count 249000
# Processing count 250000
# Processing count 251000
# Processing count 252000
# Processing count 253000
# Processing count 254000
# Processing count 255000
# Processing count 256000
# Processing count 257000
# Processing count 258000
# Processing count 259000
# Processing count 260000
# Processing count 261000
# Processing count 262000
# Processing count 263000
# Processing count 264000
# Processing count 265000
# Processing count 266000
# Processing count 267000
# Processing count 268000
# Processing count 269000
# Processing count 270000
# Processing count 271000
# Processing count 272000
# Processing count 273000
# Processing count 274000
# Processing count 275000
# Processing count 276000
# Processing count 277000
# Processing count 278000
# Processing count 279000
# Processing count 280000
# Processing count 281000
# Processing count 282000
# Processing count 283000
# Processing count 284000
# Processing count 285000
# Processing the final batch
